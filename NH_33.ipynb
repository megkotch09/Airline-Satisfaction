# %% [markdown]
# <a href="https://colab.research.google.com/github/megkotch09/Airline-Satisfacation/blob/master/NH_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install matplotlib
# !pip install folium
# !pip install requests

import pandas as pd
import geopandas as gpd
import folium
import requests
import os
import numbers
import math

from google.colab import drive
drive.mount('/content/drive')

# %%
# Set your Census Bureau API key
api_key = "8a0b76a97aa387f1d801ca752ec8983574f5c307"

# Set the base URL for the API
base_url = "https://api.census.gov/data"

# Set the variables you want to retrieve
variables = ["B01001_001E"]  # Example variables (total population, white population, Hispanic population)

# Set the geographic parameters for New Hampshire
state_fips = "33"  # New Hampshire FIPS code

# Construct the API request URL with parameters
api_url = base_url + "/2021/acs/acs5?get=" + ",".join(variables) + "&for=county%20subdivision:*&in=state:" + state_fips + "&key=" + api_key

# Send the request and get the response
response = requests.get(api_url)

# Parse the response data (assuming it's in JSON format)
data = response.json()

#print(data)

# %%
# Extract the variable names from the first row of the response
headers = ["Total", "State", "County", "County Sub"]
#headers = data[0]

# Extract the data values from the second row of the response
rows = data[1:]

# Map the variable names to their corresponding values
df = pd.DataFrame(rows, columns=headers)

#display(df) # yas slay queen

df['ALL'] = df['State'] + df['County'] + df['County Sub']
#display(df)
#print(df)

# %%
# Load shapefile data (left sidebar!!)
shapefile_path = "/content/drive/MyDrive/GT/bluebonnet!!/mine - april 2023/New Hampshire/cb_2022_33_cousub_500k/cb_2022_33_cousub_500k.shp"

shapefile = gpd.read_file(shapefile_path)

shapefile.drop(shapefile.columns[[4, 7, 8]], axis=1, inplace=True)

#print(shapefile)

json = shapefile.to_json()

df2 = pd.DataFrame(shapefile)

df = df.astype(int)
shapefile['GEOID'] = shapefile['GEOID'].astype(int)

#print(df)

# %%
merged_data = shapefile.merge(df, left_on="GEOID", right_on="ALL", how="left")
#print(merged_data)

#df['ALL'] corresponds to shapefile['GEOID']

# %%
# Create a base map centered at New Hampshire
map_center = [43.9654, -71.4742]  # Latitude and longitude of New Hampshire
m = folium.Map(location=map_center, zoom_start=8)
bins = generate_bins(15)

# %%
# Overlay the demographic data as a choropleth map
folium.Choropleth(
    geo_data=json, #this is supposed to be a json file
    name="choropleth",
    data=df, #this is supposed to be a dataframe
    #columns=["ALL", "Total", "White", "Hispanic", "Asian Indian", "Bangladeshi"],
    columns=["ALL", "Total"],
    key_on="feature.properties.GEOID",
    fill_color="Spectral",
    fill_opacity=0.9,
    line_opacity=0.2,
    legend_name="Population",
    bins=bins
).add_to(m)

folium.LayerControl().add_to(m)

# Display the map
#m.save("new_hampshire_demographics_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef83092f2a8560fe926abbe4a4b3872e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef83092f2a8560fe926abbe4a4b3872e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef83092f2a8560fe926abbe4a4b3872e = L.map(
#                 &quot;map_ef83092f2a8560fe926abbe4a4b3872e&quot;,
#                 {
#                     center: [43.9654, -71.4742],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32b191e6c4f3fa961dd2a69207f674cd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef83092f2a8560fe926abbe4a4b3872e);
#
#
#             var choropleth_98b6ac09e381b697f106d84e5e8bdbc2 = L.featureGroup(
#                 {}
#             ).addTo(map_ef83092f2a8560fe926abbe4a4b3872e);
#
#
#         function geo_json_89f8e12f4c8480fe6fcc1ad68fc0f576_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;13&quot;: case &quot;37&quot;: case &quot;45&quot;: case &quot;65&quot;: case &quot;95&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;115&quot;: case &quot;125&quot;: case &quot;133&quot;: case &quot;165&quot;: case &quot;217&quot;: case &quot;231&quot;: case &quot;243&quot;: case &quot;253&quot;: case &quot;254&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf7a3&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;34&quot;: case &quot;36&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;49&quot;: case &quot;79&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;119&quot;: case &quot;127&quot;: case &quot;146&quot;: case &quot;153&quot;: case &quot;158&quot;: case &quot;162&quot;: case &quot;179&quot;: case &quot;242&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fdca78&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;12&quot;: case &quot;16&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;40&quot;: case &quot;61&quot;: case &quot;106&quot;: case &quot;120&quot;: case &quot;123&quot;: case &quot;149&quot;: case &quot;151&quot;: case &quot;156&quot;: case &quot;157&quot;: case &quot;197&quot;: case &quot;214&quot;: case &quot;248&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3e77b5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;8&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;52&quot;: case &quot;57&quot;: case &quot;85&quot;: case &quot;129&quot;: case &quot;130&quot;: case &quot;132&quot;: case &quot;154&quot;: case &quot;160&quot;: case &quot;176&quot;: case &quot;177&quot;: case &quot;186&quot;: case &quot;241&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e25249&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;15&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;54&quot;: case &quot;59&quot;: case &quot;69&quot;: case &quot;82&quot;: case &quot;109&quot;: case &quot;126&quot;: case &quot;131&quot;: case &quot;196&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9e0142&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;43&quot;: case &quot;53&quot;: case &quot;58&quot;: case &quot;72&quot;: case &quot;74&quot;: case &quot;81&quot;: case &quot;99&quot;: case &quot;107&quot;: case &quot;116&quot;: case &quot;140&quot;: case &quot;159&quot;: case &quot;171&quot;: case &quot;181&quot;: case &quot;183&quot;: case &quot;191&quot;: case &quot;208&quot;: case &quot;238&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6fc5a4&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;100&quot;: case &quot;135&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;168&quot;: case &quot;170&quot;: case &quot;172&quot;: case &quot;174&

# %%
def generate_bins(nbins):
  quantiles = []
  for i in range(0, nbins+1):
    quantiles.append(i/nbins)

  bins = list(df['Total'].quantile(quantiles))

  return bins
